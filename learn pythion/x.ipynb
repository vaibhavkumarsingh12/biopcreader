# %%
for i in range (100,0,-1):
    print (f"{i} yu are dumb")
# Out:
# 100 yu are dumb
# 99 yu are dumb
# 98 yu are dumb
# 97 yu are dumb
# 96 yu are dumb
# 95 yu are dumb
# 94 yu are dumb
# 93 yu are dumb
# 92 yu are dumb
# 91 yu are dumb
# 90 yu are dumb
# 89 yu are dumb
# 88 yu are dumb
# 87 yu are dumb
# 86 yu are dumb
# 85 yu are dumb
# 84 yu are dumb
# 83 yu are dumb
# 82 yu are dumb
# 81 yu are dumb
# 80 yu are dumb
# 79 yu are dumb
# 78 yu are dumb
# 77 yu are dumb
# 76 yu are dumb
# 75 yu are dumb
# 74 yu are dumb
# 73 yu are dumb
# 72 yu are dumb
# 71 yu are dumb
# 70 yu are dumb
# 69 yu are dumb
# 68 yu are dumb
# 67 yu are dumb
# 66 yu are dumb
# 65 yu are dumb
# 64 yu are dumb
# 63 yu are dumb
# 62 yu are dumb
# 61 yu are dumb
# 60 yu are dumb
# 59 yu are dumb
# 58 yu are dumb
# 57 yu are dumb
# 56 yu are dumb
# 55 yu are dumb
# 54 yu are dumb
# 53 yu are dumb
# 52 yu are dumb
# 51 yu are dumb
# 50 yu are dumb
# 49 yu are dumb
# 48 yu are dumb
# 47 yu are dumb
# 46 yu are dumb
# 45 yu are dumb
# 44 yu are dumb
# 43 yu are dumb
# ...

# %%
for i in range (99,0,-1):
    print (f"{i}  bottles of beer on the wall")
    print (f"{i}  bottles of beer")
    print (f"take one down, pass it around")
# Out:
# 99  bottles of beer on the wall
# 99  bottles of beer
# take one down, pass it around
# 98  bottles of beer on the wall
# 98  bottles of beer
# take one down, pass it around
# 97  bottles of beer on the wall
# 97  bottles of beer
# take one down, pass it around
# 96  bottles of beer on the wall
# 96  bottles of beer
# take one down, pass it around
# 95  bottles of beer on the wall
# 95  bottles of beer
# take one down, pass it around
# 94  bottles of beer on the wall
# 94  bottles of beer
# take one down, pass it around
# 93  bottles of beer on the wall
# 93  bottles of beer
# take one down, pass it around
# 92  bottles of beer on the wall
# 92  bottles of beer
# take one down, pass it around
# 91  bottles of beer on the wall
# 91  bottles of beer
# take one down, pass it around
# 90  bottles of beer on the wall
# 90  bottles of beer
# take one down, pass it around
# 89  bottles of beer on the wall
# 89  bottles of beer
# take one down, pass it around
# ...

# %%
for i in range(1,101):
    if i % 15 == 0:
        print("FizzBuzz")
    elif i % 3 == 0:
        print("Fizz")
    elif i % 5 == 0:
        print("Buzz")
    else:
        print(i)
print("Done")
# Out:
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz
# Fizz
# 22
# 23
# Fizz
# Buzz
# 26
# Fizz
# 28
# 29
# FizzBuzz
# 31
# 32
# Fizz
# 34
# Buzz
# Fizz
# 37
# 38
# Fizz
# Buzz
# 41
# Fizz
# 43
# 44
# FizzBuzz
# 46
# 47
# Fizz
# 49
# Buzz
# Fizz
# 52
# 53
# Fizz
# Buzz
# 56
# Fizz
# 58
# 59
# FizzBuzz
# 61
# 62
# Fizz
# 64
# Buzz
# Fizz
# 67
# 68
# Fizz
# Buzz
# 71
# Fizz
# 73
# 74
# FizzBuzz
# 76
# 77
# Fizz
# 79
# Buzz
# Fizz
# 82
# 83
# Fizz
# Buzz
# 86
# Fizz
# 88
# 89
# FizzBuzz
# 91
# 92
# Fizz
# 94
# Buzz
# Fizz
# 97
# 98
# Fizz
# Buzz
# Done

# %%
todo = ['🏦 Get quarters.','🧺 Do laundry.'
,'🌳 Take a walk.'
,'💈 Get a haircut.'
,'🍵 Make some tea.'
,'💻 Complete Lists chapter.'
,'💖 Call mom.'
,'📺 Watch My Hero Academia.']
print(todo[0] + "and do the " + todo[1] )
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[35], line 8
#       1 todo = ['🏦 Get quarters.','🧺 Do laundry.'
#       2 ,'🌳 Take a walk.'
#       3 ,'💈 Get a haircut.'
#    (...)      6 ,'💖 Call mom.'
#       7 ,'📺 Watch My Hero Academia.']
# ----> 8 print(todo[9])
#
# IndexError: list index out of range

# %%
# Write code below 💖

list = ['Harry Potter',
'1984',
'The Fault in Our Stars',
'The Mom Test',
'Life in Code',]

list.append('Pachinko')
list.remove('The Fault in Our Stars')
list.pop(1)
print(list)
# Out:
# ['Harry Potter', 'The Mom Test', 'Life in Code', 'Pachinko']

# %%
# Mixtape Program
# 💿 Theme: Chill Vibes

# Creating a playlist of songs
playlist = [
    'Tame Impala - Let It Happen',
    'Mac DeMarco - Chamber of Reflection',
    'Beach House - Space Song',
    'Clairo - Sofia',
    'Frank Ocean - Pink + White',
    'Lana Del Rey - Venice Bitch'
]

# Looping over the playlist and printing each song
for song in playlist:
    print(song)
# Out:
# Tame Impala - Let It Happen
# Mac DeMarco - Chamber of Reflection
# Beach House - Space Song
# Clairo - Sofia
# Frank Ocean - Pink + White
# Lana Del Rey - Venice Bitch

# %%
# 💿 Theme: Indie Travel Songs

playlist = [
  'Porches - rangerover',
  'Mount Eerie - You Swan, Go On',
  'Carolyn Polachek - Look at Me Now',
  'Pinegrove - Darkness',
  'LVL UP - Spirit Was',
  'Mitski - First Love / Late Spring'
]

for i in playlist:
    print(i)
# Out:
# Porches - rangerover
# Mount Eerie - You Swan, Go On
# Carolyn Polachek - Look at Me Now
# Pinegrove - Darkness
# LVL UP - Spirit Was
# Mitski - First Love / Late Spring
